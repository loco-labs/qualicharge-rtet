# %% [markdown]
# # Tests des fonctions de calcul de la saturation - full chunk
#
# - découpage 1 : à partir des pools
# - découpage 2 : à partir des stations (après élimination des stations déja traitées)

# %%
from datetime import date

import pandas as pd
from e2_e3_e6 import e2_e3_e6, e2_e3_e6_with_details

CHUNK_SIZE: int = 200
SAMPLES: int = 288  # 5 min
SATURE_H: int = 45  # minimum duration (min) of saturation to have a saturated hour
MAX_SESSION_DURATION_HOURS = 24

ID_POC: str = "id_pdc_itinerance"
ID_STATION: str = "id_station_itinerance"
ID_POOL: str = "id_pool"
SATURATION_RATIO = 0.1
OVERLOAD_RATIO = 0.2
MIN_POWER = 75

#day = date(2026,7, 5)
#day = date(2026,7, 14)
day = date(2026,8, 1)
#day = date(2026,8, 18)
#day = date(2026,8, 25)
date_file = f"{day.year}{day.month:02d}{day.day:02d}"

data_quali = "../data/"

# %% [markdown]
# ## test qualicharge

# %%
stations = ['FRIOYP13530834']
state_poc, state_station, state_pool, sampled_state_poc, sampled_state_station = e2_e3_e6_with_details(MIN_POWER, day, CHUNK_SIZE, SAMPLES, stations)
# Out:
# chunks_pools  [    id_pdc_itinerance     id_station_itinerance  id_pool
# 0                 NaN  FRHPCPNF080371TIERSTOTEM  A000001
# 1                 NaN                FRTSLP5670  A000002
# 2                 NaN            FRIOYP13531046  A000002
# 3                 NaN            FRIOYP13530804  A000003
# 4                 NaN            FRFASP11568703  A000004
# ..                ...                       ...      ...
# 386               NaN                       NaN  A000372
# 387               NaN             FRPLNP4118449  A000373
# 388               NaN              FRVIAP103112  A000374
# 389               NaN                       NaN  A000375
# 390               NaN                       NaN  A000376
#
# [391 rows x 3 columns],      id_pdc_itinerance id_station_itinerance  id_pool
# 391       FRIOYE124871        FRIOYP13530834  A000377
# 392       FRIOYE124804        FRIOYP13530834  A000377
# 393       FRIOYE124802        FRIOYP13530834  A000377
# 394       FRIOYE124803        FRIOYP13530834  A000377
# 395       FRIOYE124801        FRIOYP13530834  A000377
# ...                ...                   ...      ...
# 1926               NaN                   NaN  A001871
# 1927               NaN                   NaN  A001872
# 1928               NaN                   NaN  A001873
# 1929               NaN                   NaN  A001874
# 1930               NaN                   NaN  A001875
#
# [1540 rows x 3 columns]]
# 0 0
# 208 724
# chunks_no_pools  []
# future0  (Empty DataFrame
# Columns: [id_pdc_itinerance, occupe, occupe_max, hors_service, libre, pseudo_libre, pseudo_occupe]
# Index: [], Empty DataFrame
# Columns: [id_station_itinerance, nb_pdc, hs, inactif, pu_cum, sature_cum, surcharge, actif, sature_max, pu_max, pu_len]
# Index: [], Empty DataFrame
# Columns: [id_pool, nb_pdc, hs, inactif, pu_cum, sature_cum, surcharge, actif, sature_max, pu_max, pu_len]
# Index: [], Empty DataFrame
# Columns: [id_pdc_itinerance, periode, state, pseudo_libre, pseudo_occupe]
# Index: [], Empty DataFrame
# Columns: [id_station_itinerance, periode, occupe, hors_service, libre, pleine_utilisation, pseudo_libre, pseudo_occupe, nb_pdc, hs, inactif, pu, sature, surcharge, actif, state]
# Index: [])
# future-1  (  id_pdc_itinerance  occupe  occupe_max  hors_service  libre  pseudo_libre  \
# 0      FRIOYE124801   980.0        60.0           0.0  460.0           0.0
# 1      FRIOYE124802  1010.0        60.0           0.0  430.0           0.0
# 2      FRIOYE124803   980.0        60.0           0.0  460.0           0.0
# 3      FRIOYE124804  1080.0        60.0           0.0  360.0           0.0
# 4      FRIOYE124871  1050.0        60.0           0.0  390.0           0.0
# 5      FRIOYE124872  1065.0        60.0           0.0  375.0           0.0
#
#    pseudo_occupe
# 0          180.0
# 1           75.0
# 2           95.0
# 3          110.0
# 4           50.0
# 5           80.0  ,   id_station_itinerance  nb_pdc   hs  inactif  pu_cum  sature_cum  surcharge  \
# 0        FRIOYP13530834       6  0.0     35.0   925.0       420.0      400.0
#
#    actif  sature_max  pu_max  pu_len
# 0  585.0        55.0    60.0   480.0  ,    id_pool  nb_pdc   hs  inactif  pu_cum  sature_cum  surcharge  actif  \
# 0  A000377       6  0.0     35.0   925.0       420.0      400.0  585.0
#
#    sature_max  pu_max  pu_len
# 0        55.0    60.0   480.0  ,      id_pdc_itinerance                   periode   state  pseudo_libre  \
# 0         FRIOYE124801 2026-08-01 00:00:00+00:00   libre         False
# 1         FRIOYE124801 2026-08-01 00:05:00+00:00   libre         False
# 2         FRIOYE124801 2026-08-01 00:10:00+00:00   libre         False
# 3         FRIOYE124801 2026-08-01 00:15:00+00:00   libre         False
# 4         FRIOYE124801 2026-08-01 00:20:00+00:00  occupe         False
# ...                ...                       ...     ...           ...
# 1723      FRIOYE124872 2026-08-01 23:35:00+00:00   libre         False
# 1724      FRIOYE124872 2026-08-01 23:40:00+00:00   libre         False
# 1725      FRIOYE124872 2026-08-01 23:45:00+00:00   libre         False
# 1726      FRIOYE124872 2026-08-01 23:50:00+00:00   libre         False
# 1727      FRIOYE124872 2026-08-01 23:55:00+00:00   libre         False
#
#       pseudo_occupe
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ...             ...
# 1723          False
# 1724          False
# 1725          False
# 1726          False
# 1727          False
#
# [1728 rows x 5 columns],     id_station_itinerance                   periode  occupe  hors_service  \
# 0          FRIOYP13530834 2026-08-01 00:00:00+00:00       0             0
# 1          FRIOYP13530834 2026-08-01 00:05:00+00:00       0             0
# 2          FRIOYP13530834 2026-08-01 00:10:00+00:00       1             0
# 3          FRIOYP13530834 2026-08-01 00:15:00+00:00       2             0
# 4          FRIOYP13530834 2026-08-01 00:20:00+00:00       4             0
# ..                    ...                       ...     ...           ...
# 283        FRIOYP13530834 2026-08-01 23:35:00+00:00       2             0
# 284        FRIOYP13530834 2026-08-01 23:40:00+00:00       2             0
# 285        FRIOYP13530834 2026-08-01 23:45:00+00:00       2             0
# 286        FRIOYP13530834 2026-08-01 23:50:00+00:00       1             0
# 287        FRIOYP13530834 2026-08-01 23:55:00+00:00       1             0
#
#      libre  pleine_utilisation  pseudo_libre  pseudo_occupe  nb_pdc     hs  \
# 0        6                   0             0              0       6  False
# 1        6                   0             0              0       6  False
# 2        5                   1             0              0       6  False
# 3        4                   2             0              0       6  False
# 4        2                   4             0              0       6  False
# ..     ...                 ...           ...            ...     ...    ...
# 283      4                   4             0              0       6  False
# 284      4                   2             0              0       6  False
# 285      4                   2             0              0       6  False
# 286      5                   2             0              0       6  False
# 287      5                   1             0              0       6  False
#
#      inactif     pu  sature  surcharge  actif  state
# 0       True  False   False      False  False      2
# 1       True  False   False      False  False      2
# 2      False  False   False      False   True      3
# 3      False  False   False      False   True      3
# 4      False  False   False      False   True      3
# ..       ...    ...     ...        ...    ...    ...
# 283    False  False   False      False   True      3
# 284    False  False   False      False   True      3
# 285    False  False   False      False   True      3
# 286    False  False   False      False   True      3
# 287    False  False   False      False   True      3
#
# [288 rows x 16 columns])

# %%
state_poc.sort_values(by=[ID_POC])
# Out:
#   id_pdc_itinerance  occupe  occupe_max  hors_service  libre  pseudo_libre  \
# 0      FRIOYE124801   980.0        60.0           0.0  460.0           0.0
# 1      FRIOYE124802  1010.0        60.0           0.0  430.0           0.0
# 2      FRIOYE124803   980.0        60.0           0.0  460.0           0.0
# 3      FRIOYE124804  1080.0        60.0           0.0  360.0           0.0
# 4      FRIOYE124871  1050.0        60.0           0.0  390.0           0.0
# 5      FRIOYE124872  1065.0        60.0           0.0  375.0           0.0
#
#    pseudo_occupe
# 0          180.0
# 1           75.0
# 2           95.0
# 3          110.0
# 4           50.0
# 5           80.0

# %%
type(state_station)
# Out:
# tuple

# %%
state_station.sort_values(by=[ID_STATION])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 state_station.sort_values(by=[ID_STATION])
#
# AttributeError: 'tuple' object has no attribute 'sort_values'

# %%
state_station[state_station[ID_STATION] == 'FRIOYP13530834']

# %%
state_station[state_station['pu_len'] >= 180]

# %%
state_pool[state_pool['pu_len'] >= 180]

# %%
state_pool[state_pool[ID_POOL] == 'A000377']

# %%
state_pool.sort_values(by=[ID_POOL])
