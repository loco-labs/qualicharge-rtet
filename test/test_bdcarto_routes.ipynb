# %%
from shapely import LineString, Point
import geopandas as gpd
import geo_nx as gnx 
import networkx as nx 
import pandas as pd
import geo_nx.utils as utils
from networkx.utils import graphs_equal

# %%
routes = gpd.read_file("../../BDCARTO/PACA/TRANSPORT/ROUTE_NUMEROTEE_OU_NOMMEE.shx")
print(routes)
# Out:
#                             ID                 ID_BDTOPO      TYPE_ROUTE  \
# 0     MEROUNUM0000002245489447  ROUTNOMM0000000038232058  Départementale
# 1     MEROUNUM0000002245491153  ROUTNOMM0000000075346586  Départementale
# 2     MEROUNUM0000002245511189  ROUTNOMM0000000074349084       Autoroute
# 3     MEROUNUM0000002245498211  ROUTNOMM0000000236207467  Départementale
# 4     MEROUNUM0000002245508059  ROUTNOMM0000000075808657  Départementale
# ...                        ...                       ...             ...
# 2126  MEROUNUM0000002245485568  ROUTNOMM0000000038231997  Départementale
# 2127  MEROUNUM0000002245504888  ROUTNOMM0000000007163237  Départementale
# 2128  MEROUNUM0000002245509230  ROUTNOMM0000000074348959  Départementale
# 2129  MEROUNUM0000002345079870  ROUTNOMM0000002340589122  Départementale
# 2130  MEROUNUM0000002245522139  ROUTNOMM0000000038232068  Départementale
#
#      NUMERO          GESTION TOPONYME STATUT_TOP  \
# 0      D118         Vaucluse     None       None
# 1      D241              Var     None       None
# 2       A10           Italie     None       None
# 3     D1009  Alpes-Maritimes     None       None
# 4      D538     Hautes-Alpes     None       None
# ...     ...              ...      ...        ...
# 2126   D104         Vaucluse     None       None
# 2127   D542            Drôme     None       None
# 2128    D78  Alpes-Maritimes     None       None
# 2129   D986         Vaucluse     None       None
# 2130    D42         Vaucluse     None       None
#
#                                                geometry
# 0     LINESTRING (888436.3 6297826.8, 888443.3 62977...
# 1     LINESTRING (971690.8 6232982.1, 971692.7 62329...
# 2     LINESTRING (1064828.4 6309386.9, 1064597.9 630...
# 3     LINESTRING (1017270.9 6284785.2, 1017384.6 628...
# 4     LINESTRING (981658 6410535.5, 981657.1 6410539...
# ...                                                 ...
# 2126  MULTILINESTRING ((878843 6312214.6, 878816.5 6...
# 2127  LINESTRING (893830.1 6341916.6, 893862.1 63419...
# 2128  LINESTRING (995576.1 6348705.1, 995583.6 63486...
# 2129  MULTILINESTRING ((832484.4 6352139.4, 832542.9...
# 2130  MULTILINESTRING ((904548.6 6300499.9, 904563.2...
#
# [2131 rows x 8 columns]

# %%
pd.pivot_table(routes, values='NUMERO', index='TYPE_ROUTE', aggfunc="count")
# Out:
#                       NUMERO
# TYPE_ROUTE
# Autoroute                 27
# Bac                        0
# Départementale          1776
# Itinéraire cyclable        0
# Liaison maritime           0
# Nationale                 16
# Route européenne           5
# Route intercommunale     143
# Route nommée               0
# Voie verte                 0

# %%
routes.loc[routes['TYPE_ROUTE']=='Route européenne']
# Out:
#                             ID                 ID_BDTOPO        TYPE_ROUTE  \
# 702   MEROUNUM0000002245511446  ROUTNOMM0000000008100698  Route européenne
# 1003  MEROUNUM0000002245490912  ROUTNOMM0000000040993471  Route européenne
# 1441  MEROUNUM0000002245520635  ROUTNOMM0000000074349290  Route européenne
# 1547  MEROUNUM0000002245513419  ROUTNOMM0000000046445649  Route européenne
# 1920  MEROUNUM0000002245482874  ROUTNOMM0000000074349194  Route européenne
#
#      NUMERO GESTION TOPONYME STATUT_TOP  \
# 702    E712    None     None       None
# 1003   E714    None     None       None
# 1441    E80    None     None       None
# 1547    E15    None     None       None
# 1920    E74    None     None       None
#
#                                                geometry
# 702   MULTILINESTRING ((896304.7 6275020.6, 896370.8...
# 1003  MULTILINESTRING ((842591.5 6339147.2, 842754.2...
# 1441  MULTILINESTRING ((339518.8 6274109.6, 339397.5...
# 1547  MULTILINESTRING ((622714.9 7093874.3, 622793.6...
# 1920  MULTILINESTRING ((1045876.8 6302021.7, 1045754...

# %%
routes.loc[routes['TYPE_ROUTE']=='Autoroute']
# Out:
#                             ID                 ID_BDTOPO TYPE_ROUTE NUMERO  \
# 2     MEROUNUM0000002245511189  ROUTNOMM0000000074349084  Autoroute    A10
# 177   MEROUNUM0000002245490897  ROUTNOMM0000000040993409  Autoroute   A552
# 202   MEROUNUM0000002245490959  ROUTNOMM0000000040993486  Autoroute   A501
# 231   MEROUNUM0000002245490846  ROUTNOMM0000002006457733  Autoroute   A517
# 348   MEROUNUM0000002245490992  ROUTNOMM0000000040993433  Autoroute   A520
# 460   MEROUNUM0000002245513196  ROUTNOMM0000000075346613  Autoroute   A570
# 465   MEROUNUM0000002245490961  ROUTNOMM0000000227922961  Autoroute   A501
# 653   MEROUNUM0000002245490901  ROUTNOMM0000000040993408  Autoroute   A551
# 660   MEROUNUM0000002245490936  ROUTNOMM0000000040993370  Autoroute   A515
# 1010  MEROUNUM0000002245522271  ROUTNOMM0000000227925313  Autoroute    A57
# 1022  MEROUNUM0000002245518678  ROUTNOMM0000002000595798  Autoroute   A507
# 1027  MEROUNUM0000002245515249  ROUTNOMM0000000227925060  Autoroute     A7
# 1211  MEROUNUM0000002245522060  ROUTNOMM0000000040993407  Autoroute    A51
# 1217  MEROUNUM0000002245490987  ROUTNOMM0000000040993483  Autoroute   A502
# 1259  MEROUNUM0000002245486129  ROUTNOMM0000002006457734  Autoroute    A55
# 1318  MEROUNUM0000002245490902  ROUTNOMM0000000040993458  Autoroute   A557
# 1514  MEROUNUM0000002245500424  ROUTNOMM0000000040993321  Autoroute     A8
# 1517  MEROUNUM0000002245512200  ROUTNOMM0000000007163158  Autoroute     A7
# 1537  MEROUNUM0000002245507956  ROUTNOMM0000000074349292  Autoroute     A8
# 1666  MEROUNUM0000002245519263  ROUTNOMM0000000044995398  Autoroute     A9
# 1722  MEROUNUM0000002245499948  ROUTNOMM0000000074349136  Autoroute   A500
# 1787  MEROUNUM0000002245513723  ROUTNOMM0000000075346616  Autoroute    A57
# 1924  MEROUNUM0000002245488383  ROUTNOMM0000000040993511  Autoroute    A50
# 1926  MEROUNUM0000002245487357  ROUTNOMM0000000075346618  Autoroute    A50
# 1939  MEROUNUM0000002245502871  ROUTNOMM0000000027985822  Autoroute    A54
# 2033  MEROUNUM0000002245488384  ROUTNOMM0000000040993496  Autoroute    A52
# 2097  MEROUNUM0000002245507369  ROUTNOMM0000000037685111  Autoroute    A51
#
#                GESTION TOPONYME STATUT_TOP  \
# 2               Italie     None       None
# 177   DIR Méditerranée     None       None
# 202             ESCOTA     None       None
# 231   DIR Méditerranée     None       None
# 348             ESCOTA     None       None
# 460   DIR Méditerranée     None       None
# 465   DIR Méditerranée     None       None
# 653   DIR Méditerranée     None       None
# 660   DIR Méditerranée     None       None
# 1010  DIR Méditerranée     None       None
# 1022  DIR Méditerranée     None       None
# 1027  DIR Méditerranée     None       None
# 1211  DIR Méditerranée     None       None
# 1217  DIR Méditerranée     None       None
# 1259  DIR Méditerranée     None       None
# 1318  DIR Méditerranée     None       None
# 1514               ASF     None       None
# 1517               ASF     None       None
# 1537            ESCOTA     None       None
# 1666               ASF     None       None
# 1722            ESCOTA     None       None
# 1787            ESCOTA     None       None
# 1924  DIR Méditerranée     None       None
# 1926            ESCOTA     None       None
# 1939               ASF     None       None
# 2033            ESCOTA     None       None
# 2097            ESCOTA     None       None
#
#                                                geometry
# 2     LINESTRING (1064828.4 6309386.9, 1064597.9 630...
# 177   LINESTRING (886999 6258778.4, 886936.6 6258769...
# 202   LINESTRING (910567 6250394.2, 910565.2 6250392...
# 231   MULTILINESTRING ((890981.6 6258838, 890858.8 6...
# 348   MULTILINESTRING ((912629.2 6253990.6, 912598.7...
# 460   LINESTRING (946795.5 6231927.3, 946816.1 62319...
# 465   LINESTRING (908534.1 6248262.9, 908515.3 62482...
# 653   LINESTRING (885590.3 6259112.8, 885667 6259062...
# 660   MULTILINESTRING ((893288.4 6261682.3, 893431 6...
# 1010  LINESTRING (946062.7 6231885.2, 946220.5 62319...
# 1022  MULTILINESTRING ((892524 6252534.8, 892632.4 6...
# 1027  MULTILINESTRING ((881139.2 6269110.8, 881178.6...
# 1211  LINESTRING (896394.9 6273253.6, 896290.2 62729...
# 1217  LINESTRING (910634.4 6246222.4, 910439.8 62462...
# 1259  MULTILINESTRING ((863756.2 6259137, 864173.2 6...
# 1318  LINESTRING (892991.1 6250114.4, 892967.4 62500...
# 1514  MULTILINESTRING ((879868.6 6276559.6, 879917.2...
# 1517  MULTILINESTRING ((843211 6487795.3, 843209.9 6...
# 1537  MULTILINESTRING ((896342.2 6271891.2, 896351.9...
# 1666  MULTILINESTRING ((685194.6 6158423, 685239.9 6...
# 1722  MULTILINESTRING ((1051606.5 6303756.5, 1051807...
# 1787  MULTILINESTRING ((972154.7 6261133.8, 972118.9...
# 1924  MULTILINESTRING ((894697.6 6245587.2, 894702.6...
# 1926  MULTILINESTRING ((908992.4 6246142.9, 909093.5...
# 1939  MULTILINESTRING ((808285.5 6302076.1, 808224.7...
# 2033  MULTILINESTRING ((907173 6268187.9, 907081.6 6...
# 2097  LINESTRING (940921.7 6376064.3, 940946.7 63760...

# %%
type_route = list(pd.unique(routes['TYPE_ROUTE']))
type_route
# Out:
# ['Départementale',
#  'Autoroute',
#  'Route intercommunale',
#  'Itinéraire cyclable',
#  'Nationale',
#  'Route nommée',
#  'Liaison maritime',
#  'Bac',
#  'Route européenne',
#  'Voie verte']

# %%
types_route = ['Autoroute', 'Nationale',  'Route européenne']

# %%
routes = routes.set_index('TYPE_ROUTE')

# %%
troncons = routes.loc[types_route, ['ID', 'geometry', 'NUMERO', 'GESTION']]  # -> 75
troncons_gpd = gpd.GeoDataFrame(troncons, crs=2154).reset_index()
print(troncons_gpd)
troncons_gpd.to_file("../../BDCARTO/troncons.geojson", driver= "GeoJSON")
# Out:
#           TYPE_ROUTE                        ID  \
# 0          Autoroute  MEROUNUM0000002245511189
# 1          Autoroute  MEROUNUM0000002245490897
# 2          Autoroute  MEROUNUM0000002245490959
# 3          Autoroute  MEROUNUM0000002245490846
# 4          Autoroute  MEROUNUM0000002245490992
# 5          Autoroute  MEROUNUM0000002245513196
# 6          Autoroute  MEROUNUM0000002245490961
# 7          Autoroute  MEROUNUM0000002245490901
# 8          Autoroute  MEROUNUM0000002245490936
# 9          Autoroute  MEROUNUM0000002245522271
# 10         Autoroute  MEROUNUM0000002245518678
# 11         Autoroute  MEROUNUM0000002245515249
# 12         Autoroute  MEROUNUM0000002245522060
# 13         Autoroute  MEROUNUM0000002245490987
# 14         Autoroute  MEROUNUM0000002245486129
# 15         Autoroute  MEROUNUM0000002245490902
# 16         Autoroute  MEROUNUM0000002245500424
# 17         Autoroute  MEROUNUM0000002245512200
# 18         Autoroute  MEROUNUM0000002245507956
# 19         Autoroute  MEROUNUM0000002245519263
# 20         Autoroute  MEROUNUM0000002245499948
# 21         Autoroute  MEROUNUM0000002245513723
# 22         Autoroute  MEROUNUM0000002245488383
# 23         Autoroute  MEROUNUM0000002245487357
# 24         Autoroute  MEROUNUM0000002245502871
# 25         Autoroute  MEROUNUM0000002245488384
# 26         Autoroute  MEROUNUM0000002245507369
# 27         Nationale  MEROUNUM0000002245514276
# 28         Nationale  MEROUNUM0000002245491098
# 29         Nationale  MEROUNUM0000002245516682
# 30         Nationale  MEROUNUM0000002245503026
# 31         Nationale  MEROUNUM0000002245515283
# 32         Nationale  MEROUNUM0000002332536577
# 33         Nationale  MEROUNUM0000002245490856
# 34         Nationale  MEROUNUM0000002245503269
# 35         Nationale  MEROUNUM0000002245509157
# 36         Nationale  MEROUNUM0000002245519863
# 37         Nationale  MEROUNUM0000002245513443
# 38         Nationale  MEROUNUM0000002245481876
# 39         Nationale  MEROUNUM0000002245501321
# 40         Nationale  MEROUNUM0000002245512309
# 41         Nationale  MEROUNUM0000002245499856
# 42         Nationale  MEROUNUM0000002245511560
# 43  Route européenne  MEROUNUM0000002245511446
# 44  Route européenne  MEROUNUM0000002245490912
# 45  Route européenne  MEROUNUM0000002245520635
# 46  Route européenne  MEROUNUM0000002245513419
# 47  Route européenne  MEROUNUM0000002245482874
#
#                                              geometry NUMERO           GESTION
# 0   LINESTRING (1064828.4 6309386.9, 1064597.9 630...    A10            Italie
# 1   LINESTRING (886999 6258778.4, 886936.6 6258769...   A552  DIR Méditerranée
# 2   LINESTRING (910567 6250394.2, 910565.2 6250392...   A501            ESCOTA
# 3   MULTILINESTRING ((890981.6 6258838, 890858.8 6...   A517  DIR Méditerranée
# 4   MULTILINESTRING ((912629.2 6253990.6, 912598.7...   A520            ESCOTA
# 5   LINESTRING (946795.5 6231927.3, 946816.1 62319...   A570  DIR Méditerranée
# 6   LINESTRING (908534.1 6248262.9, 908515.3 62482...   A501  DIR Méditerranée
# 7   LINESTRING (885590.3 6259112.8, 885667 6259062...   A551  DIR Méditerranée
# 8   MULTILINESTRING ((893288.4 6261682.3, 893431 6...   A515  DIR Méditerranée
# 9   LINESTRING (946062.7 6231885.2, 946220.5 62319...    A57  DIR Méditerranée
# 10  MULTILINESTRING ((892524 6252534.8, 892632.4 6...   A507  DIR Méditerranée
# 11  MULTILINESTRING ((881139.2 6269110.8, 881178.6...     A7  DIR Méditerranée
# 12  LINESTRING (896394.9 6273253.6, 896290.2 62729...    A51  DIR Méditerranée
# 13  LINESTRING (910634.4 6246222.4, 910439.8 62462...   A502  DIR Méditerranée
# 14  MULTILINESTRING ((863756.2 6259137, 864173.2 6...    A55  DIR Méditerranée
# 15  LINESTRING (892991.1 6250114.4, 892967.4 62500...   A557  DIR Méditerranée
# 16  MULTILINESTRING ((879868.6 6276559.6, 879917.2...     A8               ASF
# 17  MULTILINESTRING ((843211 6487795.3, 843209.9 6...     A7               ASF
# 18  MULTILINESTRING ((896342.2 6271891.2, 896351.9...     A8            ESCOTA
# 19  MULTILINESTRING ((685194.6 6158423, 685239.9 6...     A9               ASF
# 20  MULTILINESTRING ((1051606.5 6303756.5, 1051807...   A500            ESCOTA
# 21  MULTILINESTRING ((972154.7 6261133.8, 972118.9...    A57            ESCOTA
# 22  MULTILINESTRING ((894697.6 6245587.2, 894702.6...    A50  DIR Méditerranée
# 23  MULTILINESTRING ((908992.4 6246142.9, 909093.5...    A50            ESCOTA
# 24  MULTILINESTRING ((808285.5 6302076.1, 808224.7...    A54               ASF
# 25  MULTILINESTRING ((907173 6268187.9, 907081.6 6...    A52            ESCOTA
# 26  LINESTRING (940921.7 6376064.3, 940946.7 63760...    A51            ESCOTA
# 27  MULTILINESTRING ((896479.1 6271467.6, 896477.7...  N2516  DIR Méditerranée
# 28  LINESTRING (953271.2 6229113.8, 953323.3 62290...    N98  DIR Méditerranée
# 29  MULTILINESTRING ((896304.7 6275020.6, 896370.8...   N296  DIR Méditerranée
# 30  MULTILINESTRING ((842081.1 6316108.2, 842190 6...  N1007  DIR Méditerranée
# 31  MULTILINESTRING ((853170.2 6266570.8, 853188.4...   P544              GPMM
# 32  LINESTRING (942576.8 6389030.1, 942578.6 63890...  N1085  DIR Méditerranée
# 33  MULTILINESTRING ((825694.2 6288348.8, 825706.5...   N572  DIR Méditerranée
# 34  MULTILINESTRING ((855009.7 6262281.2, 854933.1...   P545              GPMM
# 35  LINESTRING (970144.8 6322754.8, 970180.7 63228...   N202  DIR Méditerranée
# 36  LINESTRING (863195.8 6284594.7, 863220.8 62844...   N569  DIR Méditerranée
# 37  MULTILINESTRING ((917582.9 6446395.4, 917615.3...    N85  DIR Méditerranée
# 38  LINESTRING (995315.2 6433298.9, 995249 6433246...    N94  DIR Méditerranée
# 39  MULTILINESTRING ((713145.7 6650776.1, 713134.9...     N7    DIR Centre Est
# 40  LINESTRING (829487.8 6342418.1, 829537.3 63426...    N86  DIR Méditerranée
# 41  MULTILINESTRING ((840165.2 6283396.7, 840273.4...   N568  DIR Méditerranée
# 42  MULTILINESTRING ((807892.6 6302756.6, 807746.9...   N113  DIR Méditerranée
# 43  MULTILINESTRING ((896304.7 6275020.6, 896370.8...   E712              None
# 44  MULTILINESTRING ((842591.5 6339147.2, 842754.2...   E714              None
# 45  MULTILINESTRING ((339518.8 6274109.6, 339397.5...    E80              None
# 46  MULTILINESTRING ((622714.9 7093874.3, 622793.6...    E15              None
# 47  MULTILINESTRING ((1045876.8 6302021.7, 1045754...    E74              None

# %%
rtet = gpd.read_file("../../BDCARTO/troncons.geojson").to_crs(2154)

gr = gnx.from_geopandas_edgelist(rtet, edge_attr=True)
nx.set_node_attributes(gr, "connecteur", name="nature")

# %%
sub_euro = nx.subgraph_view(gr, filter_edge=lambda x,y: gr[x][y]["TYPE_ROUTE"] == 'Route européenne')
gr_euro =  nx.induced_subgraph(sub_euro, nx.utils.flatten(sub_euro.edges()))
len(gr_euro.edges)
# Out:
# 5

# %%
sub_auto = nx.subgraph_view(gr, filter_edge=lambda x,y: gr[x][y]["TYPE_ROUTE"] == 'Autoroute')
gr_autoroute =  nx.induced_subgraph(sub_auto, nx.utils.flatten(sub_auto.edges()))

# %%
sub_nat = nx.subgraph_view(gr, filter_edge=lambda x,y: gr[x][y]["TYPE_ROUTE"] == 'Nationale')
gr_nat =  nx.induced_subgraph(sub_nat, nx.utils.flatten(sub_nat.edges()))

# %%
refnat = {'tiles': 'cartodbpositron', 'location': [46.3, 2.3], 'zoom_start': 7}
param_exp_nd = {'n_marker_kwds': {'radius': 3, 'fill': True}}
param_exp_gr = {'e_popup': ['weight', 'source', 'target', 'TYPE_ROUTE'], 'e_tooltip': ["source", "target", "TYPE_ROUTE"], 
                'n_tooltip': ["node_id"], 'n_marker_kwds': {'radius': 1, 'fill': False}}


carte = gr.explore(refmap=refnat, n_color='black', e_name='edges gr', n_name='nodes gr', **param_exp_gr)
carte = gr_euro.explore(refmap=carte, e_color='green', e_name='edges euro', n_name='nodes euro', n_color='black', **param_exp_gr)
carte = gr_nat.explore(refmap=carte, e_color='magenta', e_name='edges nat', n_name='nodes nat',  n_color='black', **param_exp_gr)
carte = gr_autoroute.explore(refmap=carte, e_color='cyan', e_name='edges auto', n_name='nodes auto', layercontrol=True, n_color='black', **param_exp_gr)
carte
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0bb526ce62d678cb5048ec663a65405d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt
